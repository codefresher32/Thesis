# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Traffic_most_frequent_road_dataset.csv")
df
# Out:
#        Start_Lat   Start_Lng  Time  Temperature(F)  Visibility(mi)  \
# 0      33.638980 -117.730350   433            58.0            10.0
# 1      47.549580 -122.313470  1030            52.0            10.0
# 2      33.686620 -117.766000   843            71.1            10.0
# 3      47.974910 -122.190790  1073            61.0            10.0
# 4      35.363611 -119.347778   722            83.0            10.0
# ...          ...         ...   ...             ...             ...
# 26640  33.700624 -117.775189    41            51.0            10.0
# 26641  42.858170 -123.246925  1238            47.0             0.5
# 26642  36.532448 -120.489860   872            79.0            10.0
# 26643  47.656780 -122.322440   393            50.0            10.0
# 26644  45.381390 -122.752780   711            78.0            10.0
#
#        Humidity(%) Weather_Condition  Amenity   Bump  Crossing  Give_Way  \
# 0             84.0            Cloudy    False  False     False     False
# ...

# %%
df['Weather_Condition'].value_counts(dropna = False)
# Out:
# Fair                            7578
# Clear                           3749
# Mostly Cloudy                   3170
# Cloudy                          2786
# Partly Cloudy                   2179
# Light Rain                      2061
# Overcast                        1909
# Scattered Clouds                 652
# Fog                              642
# Haze                             531
# Rain                             391
# NaN                              237
# Light Snow                       177
# Smoke                            144
# Heavy Rain                       124
# Snow                              62
# Fair / Windy                      43
# Mist                              21
# Light Drizzle                     21
# Cloudy / Windy                    21
# Light Rain / Windy                20
# Heavy Snow                        17
# Light Freezing Fog                13
# Shallow Fog                       12
# Patches of Fog                    11
# ...

# %%
df['Weather_Condition'] = df['Weather_Condition'].fillna(df['Weather_Condition'].mode()[0])

# %%
df['Weather_Condition'].value_counts(dropna = False)
# Out:
# Fair                            7815
# Clear                           3749
# Mostly Cloudy                   3170
# Cloudy                          2786
# Partly Cloudy                   2179
# Light Rain                      2061
# Overcast                        1909
# Scattered Clouds                 652
# Fog                              642
# Haze                             531
# Rain                             391
# Light Snow                       177
# Smoke                            144
# Heavy Rain                       124
# Snow                              62
# Fair / Windy                      43
# Mist                              21
# Cloudy / Windy                    21
# Light Drizzle                     21
# Light Rain / Windy                20
# Heavy Snow                        17
# Light Freezing Fog                13
# Shallow Fog                       12
# Patches of Fog                    11
# T-Storm                           10
# ...

# %%
df.to_csv('Traffic_most_frequent_road_dataset_after_prepocessed.csv', index = False)
